# %%
import pandas as pd
HP_PEC_NToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/HP_PEC_NToma_matrix.csv", index_col = 0)
HP_PEC_PToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/HP_PEC_PToma_matrix.csv", index_col = 0)
IL4_PEC_NToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/IL4_PEC_NToma_matrix.csv", index_col = 0)
IL4_PEC_PToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/IL4_PEC_PToma_matrix.csv", index_col = 0)
SS_PEC_NToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/SS_PEC_NToma_matrix.csv", index_col = 0)
SS_PEC_PToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/SS_PEC_PToma_matrix.csv", index_col = 0)
ThioIL4PCD206_PEC_PToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/ThioIL4PCD206_PEC_PToma_matrix.csv", index_col = 0)
ThioPCD206_PEC_PToma = pd.read_csv("/home/sun/monocyte_scRNAseq/new_data/ThioPCD206_PEC_PToma_matrix.csv", index_col = 0)

# %%
intersect_genes = list(set(HP_PEC_NToma.index) & set(HP_PEC_PToma.index) & set(IL4_PEC_NToma.index) & set(IL4_PEC_PToma.index) & 
                       set(SS_PEC_NToma.index) & set(SS_PEC_PToma.index) & set(ThioIL4PCD206_PEC_PToma.index) & set(ThioPCD206_PEC_PToma.index))

# %%
HP_PEC_NToma_inter = HP_PEC_NToma.loc[intersect_genes].T
HP_PEC_NToma_inter["condition"] = "HP_PEC_NToma"
HP_PEC_PToma_inter = HP_PEC_PToma.loc[intersect_genes].T
HP_PEC_PToma_inter["condition"] = "HP_PEC_PToma"

IL4_PEC_NToma_inter = IL4_PEC_NToma.loc[intersect_genes].T
IL4_PEC_NToma_inter["condition"] = "IL4_PEC_NToma"
IL4_PEC_PToma_inter = IL4_PEC_PToma.loc[intersect_genes].T
IL4_PEC_PToma_inter["condition"] = "IL4_PEC_PToma"

SS_PEC_NToma_inter = SS_PEC_NToma.loc[intersect_genes].T
SS_PEC_NToma_inter["condition"] = "SS_PEC_NToma"
SS_PEC_PToma_inter = SS_PEC_PToma.loc[intersect_genes].T
SS_PEC_PToma_inter["condition"] = "SS_PEC_PToma"

ThioIL4PCD206_PEC_PToma_inter = ThioIL4PCD206_PEC_PToma.loc[intersect_genes].T
ThioIL4PCD206_PEC_PToma_inter["condition"] = "ThioIL4PCD206_PEC_PToma"
ThioPCD206_PEC_PToma_inter = ThioPCD206_PEC_PToma.loc[intersect_genes].T
ThioPCD206_PEC_PToma_inter["condition"] = "ThioPCD206_PEC_PToma"

# %%
data_inter_all = pd.concat([HP_PEC_NToma_inter, HP_PEC_PToma_inter, IL4_PEC_NToma_inter, IL4_PEC_PToma_inter, SS_PEC_NToma_inter, SS_PEC_PToma_inter, ThioIL4PCD206_PEC_PToma_inter, ThioPCD206_PEC_PToma_inter])

# %%
data_inter_all
# Out:
# X                   Ebf1     Cenpe    Pou2f2      Tpx2       Tk1     Hspa5  \
# AAACCTGAGTGGGCTA.1   0.0  0.000000  0.000000  0.000000  0.000000  1.219332
# AAACCTGAGTTGAGAT.1   0.0  0.000000  0.000000  0.000000  0.000000  1.727758
# AAACCTGTCGGAGCAA.1   0.0  0.674201  0.000000  0.000000  1.357738  0.674201
# AAACGGGAGGCAATTA.1   0.0  0.000000  0.000000  1.625742  0.000000  2.054591
# AAACGGGAGTCTCCTC.1   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# ...                  ...       ...       ...       ...       ...       ...
# TTTGTCAGTCAAACTC.1   0.0  0.000000  0.438476  0.000000  0.000000  0.974947
# TTTGTCAGTCCGACGT.1   0.0  0.000000  0.000000  0.000000  0.000000  0.748269
# TTTGTCATCCACGTGG.1   0.0  0.000000  0.000000  0.000000  0.000000  1.128339
# TTTGTCATCGCTTAGA.1   0.0  0.000000  0.000000  0.504117  0.000000  0.000000
# TTTGTCATCTCTAGGA.1   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
# X                       Cd55  Kcnip4  H2-DMb2  Hist1h1c  ...  Cenpp      Rrm1  \
# AAACCTGAGTGGGCTA.1  0.000000     0.0      0.0  1.219332  ...    0.0  0.000000
# AAACCTGAGTTGAGAT.1  0.000000     0.0      0.0  0.768721  ...    0.0  0.000000
# AAACCTGTCGGAGCAA.1  0.000000     0.0      0.0  0.674201  ...    0.0  0.674201
# AAACGGGAGGCAATTA.1  0.000000     0.0      0.0  0.000000  ...    0.0  0.858971
# AAACGGGAGTCTCCTC.1  1.323041     0.0      0.0  0.000000  ...    0.0  0.000000
# ...                      ...     ...      ...       ...  ...    ...       ...
# TTTGTCAGTCAAACTC.1  0.000000     0.0      0.0  0.243081  ...    0.0  0.000000
# TTTGTCAGTCCGACGT.1  0.000000     0.0      0.0  0.315623  ...    0.0  0.555163
# TTTGTCATCCACGTGG.1  0.000000     0.0      0.0  0.000000  ...    0.0  0.000000
# TTTGTCATCGCTTAGA.1  0.000000     0.0      0.0  0.504117  ...    0.0  0.000000
# TTTGTCATCTCTAGGA.1  0.000000     0.0      0.0  0.000000  ...    0.0  0.000000
#
# X                     Cdkn2a     H2afx       F10  Ikzf3  BE692007  Cavin3  \
# AAACCTGAGTGGGCTA.1  0.000000  0.000000  2.355150    0.0       0.0     0.0
# AAACCTGAGTTGAGAT.1  0.000000  0.000000  0.768721    0.0       0.0     0.0
# AAACCTGTCGGAGCAA.1  0.674201  1.073270  1.578949    0.0       0.0     0.0
# AAACGGGAGGCAATTA.1  0.000000  0.000000  0.000000    0.0       0.0     0.0
# AAACGGGAGTCTCCTC.1  0.000000  0.000000  1.873284    0.0       0.0     0.0
# ...                      ...       ...       ...    ...       ...     ...
# TTTGTCAGTCAAACTC.1  0.000000  0.438476  0.865358    0.0       0.0     0.0
# TTTGTCAGTCCGACGT.1  0.000000  0.315623  0.910051    0.0       0.0     0.0
# TTTGTCATCCACGTGG.1  0.000000  0.000000  0.000000    0.0       0.0     0.0
# TTTGTCATCGCTTAGA.1  0.000000  0.000000  0.504117    0.0       0.0     0.0
# TTTGTCATCTCTAGGA.1  0.000000  0.000000  1.964692    0.0       0.0     0.0
#
# X                      Pclaf             condition
# AAACCTGAGTGGGCTA.1  0.000000          HP_PEC_NToma
# AAACCTGAGTTGAGAT.1  0.000000          HP_PEC_NToma
# AAACCTGTCGGAGCAA.1  2.046046          HP_PEC_NToma
# AAACGGGAGGCAATTA.1  2.770588          HP_PEC_NToma
# AAACGGGAGTCTCCTC.1  0.000000          HP_PEC_NToma
# ...                      ...                   ...
# TTTGTCAGTCAAACTC.1  0.000000  ThioPCD206_PEC_PToma
# TTTGTCAGTCCGACGT.1  0.000000  ThioPCD206_PEC_PToma
# TTTGTCATCCACGTGG.1  0.000000  ThioPCD206_PEC_PToma
# TTTGTCATCGCTTAGA.1  0.000000  ThioPCD206_PEC_PToma
# TTTGTCATCTCTAGGA.1  0.000000  ThioPCD206_PEC_PToma
#
# [28801 rows x 266 columns]

# %%
data_inter_all['condition'].value_counts()/len(data_inter_all)
# Out:
# IL4_PEC_NToma              0.220826
# HP_PEC_PToma               0.133537
# HP_PEC_NToma               0.132183
# IL4_PEC_PToma              0.126072
# SS_PEC_NToma               0.120517
# ThioPCD206_PEC_PToma       0.111211
# ThioIL4PCD206_PEC_PToma    0.105969
# SS_PEC_PToma               0.049686
# Name: condition, dtype: float64

# %%
import numpy as np
X = data_inter_all.loc[:,data_inter_all.columns[:-1]]
y = data_inter_all['condition']

# %%
from sklearn.model_selection import train_test_split
import random
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# instantiate the classifier with n_estimators = 100

rfc = RandomForestClassifier(n_estimators=200, random_state=0)



# fit the model to the training set

rfc.fit(X_train, y_train)



# Predict on the test set results

y_pred = rfc.predict(X_test)



# Check accuracy score 

print('Model accuracy score with 200 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 200 decision-trees : 0.8521

# %%
import pickle
# save model
filename = '/home/sun/monocyte_scRNAseq/save_model/RF_200_7_3_all.sav'
pickle.dump(rfc, open(filename, 'wb'))

# %%
import pickle
with open('/home/sun/monocyte_scRNAseq/save_model/RF_200_7_3_all.sav', 'rb') as f:
    rfc = pickle.load(f)

# %%
# view the feature scores

feature_scores = pd.Series(rfc.feature_importances_, index=X_train.columns).sort_values(ascending=False)
feature_scores
# Out:
# X
# Retnla           0.060204
# Apoe             0.056895
# Saa3             0.046700
# Arg1             0.037132
# Prg4             0.036708
#                    ...
# Slc44a4          0.000028
# Ighd             0.000027
# Gimap4           0.000027
# Nkg7             0.000025
# 2010309G21Rik    0.000008
# Length: 265, dtype: float64

# %%
feature_scores_top40 = feature_scores.loc[feature_scores.index[:30]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 8))
ax = sns.barplot(x=feature_scores_top40, y=feature_scores_top40.index)
#ax.set_title("Visualize feature scores of the features")
ax.set_yticklabels(feature_scores_top40.index)
ax.set_xlabel("Gini importance score")
ax.set_ylabel("Top 30 genes")
plt.show()

# %%
data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0)
# Out:
# X                          Retnla      Apoe      Saa3      Arg1      Prg4  \
# condition
# HP_PEC_NToma             3.424548  1.006032  3.982356  2.461090  3.018612
# HP_PEC_PToma             3.985334  1.523834  3.824384  2.689699  2.805707
# IL4_PEC_NToma            5.699055  0.676687  5.097136  2.487364  2.354775
# IL4_PEC_PToma            5.608158  1.167165  5.619777  2.540170  2.489546
# SS_PEC_NToma             1.382931  5.492543  3.918648  0.218003  3.765631
# SS_PEC_PToma             2.888250  5.721269  4.113107  0.315825  3.686857
# ThioIL4PCD206_PEC_PToma  5.091044  0.432316  0.072567  3.822934  0.007408
# ThioPCD206_PEC_PToma     0.035920  3.755652  0.275381  0.239253  0.010654
#
# X                           Plac8    Lgals1    Tmsb10     Ccl24     Apoc2  \
# condition
# HP_PEC_NToma             0.270971  0.072159  1.758234  1.024009  0.735231
# HP_PEC_PToma             1.185178  0.169344  2.473749  1.090017  1.216736
# IL4_PEC_NToma            0.053010  0.112333  2.797925  0.544248  0.136942
# IL4_PEC_PToma            0.256899  0.203586  2.772076  0.662364  0.322101
# SS_PEC_NToma             0.031087  0.454618  0.938601  1.389986  1.444153
# SS_PEC_PToma             0.092646  0.523106  1.204046  1.572806  1.945052
# ThioIL4PCD206_PEC_PToma  0.068161  3.110764  3.877718  2.660919  0.049266
# ThioPCD206_PEC_PToma     0.067669  3.622603  4.249008  0.044121  0.510167
#
# X                        ...      Cd63     Trem2      Mgl2      Cd36  \
# condition                ...
# HP_PEC_NToma             ...  0.108375  0.110042  0.467266  0.297924
# HP_PEC_PToma             ...  0.055489  0.126425  0.582801  0.391225
# IL4_PEC_NToma            ...  0.085125  0.101114  0.726454  0.797525
# IL4_PEC_PToma            ...  0.105001  0.138670  0.684889  0.909271
# SS_PEC_NToma             ...  0.223404  0.252139  0.021590  1.489123
# SS_PEC_PToma             ...  0.120136  0.270297  0.041569  1.616565
# ThioIL4PCD206_PEC_PToma  ...  1.929310  1.119984  2.009783  2.362643
# ThioPCD206_PEC_PToma     ...  2.562290  2.530785  0.010514  2.124354
#
# X                           Fabp5  Ifi27l2a      Cd5l       Vim     Hspa5  \
# condition
# HP_PEC_NToma             0.758492  2.221179  2.248272  1.653273  1.361899
# HP_PEC_PToma             1.033313  2.200865  2.067070  1.702129  1.440679
# IL4_PEC_NToma            0.973723  2.107441  2.211108  1.760195  1.063519
# IL4_PEC_PToma            1.105889  2.011977  2.224257  1.739486  1.049869
# SS_PEC_NToma             0.598674  3.139355  1.471552  0.721193  0.712882
# SS_PEC_PToma             0.665822  2.971337  1.484309  1.000421  0.811393
# ThioIL4PCD206_PEC_PToma  2.562040  0.830628  0.229731  2.565311  2.281538
# ThioPCD206_PEC_PToma     3.852047  2.224024  0.495607  3.061798  0.720419
#
# X                           H2-Aa
# condition
# HP_PEC_NToma             0.783137
# HP_PEC_PToma             1.410116
# IL4_PEC_NToma            0.463038
# IL4_PEC_PToma            1.042401
# SS_PEC_NToma             0.172941
# SS_PEC_PToma             0.381542
# ThioIL4PCD206_PEC_PToma  1.054412
# ThioPCD206_PEC_PToma     0.240612
#
# [8 rows x 30 columns]

# %%
data_inter_all_expressed = pd.DataFrame(np.array(data_inter_all[feature_scores_top40.index.tolist()] >0, dtype=int), 
                                        columns=feature_scores_top40.index.tolist(), index=data_inter_all.index)

# %%
data_inter_all_expressed['condition'] = data_inter_all["condition"]

# %%
data_inter_all_expressed.groupby("condition").sum(0)
# Out:
#                          Retnla  Apoe  Saa3  Arg1  Prg4  Plac8  Lgals1  \
# condition
# HP_PEC_NToma               3732  1953  3804  3541  3774    776     240
# HP_PEC_PToma               3835  2846  3842  3747  3815   2836     628
# IL4_PEC_NToma              6359  2783  6355  5962  6090    244     502
# IL4_PEC_PToma              3630  2571  3631  3508  3514    731     585
# SS_PEC_NToma               1939  3469  3447   536  3448     58     982
# SS_PEC_PToma               1329  1430  1428   329  1407     79     495
# ThioIL4PCD206_PEC_PToma    3052  1060   185  3023    23    222    2997
# ThioPCD206_PEC_PToma         84  3195   620   630    30    286    3174
#
#                          Tmsb10  Ccl24  Apoc2  ...  Cd63  Trem2  Mgl2  Cd36  \
# condition                                      ...
# HP_PEC_NToma               3118   2609   1790  ...   349    372  1355   875
# HP_PEC_PToma               3631   2970   2822  ...   212    528  1883  1265
# IL4_PEC_NToma              6003   2540    681  ...   385    513  3061  3284
# IL4_PEC_PToma              3512   1916    993  ...   332    484  1788  2344
# SS_PEC_NToma               1875   2474   2442  ...   533    616    57  2636
# SS_PEC_PToma               1020   1208   1278  ...   136    317    51  1260
# ThioIL4PCD206_PEC_PToma    3016   2888    158  ...  2789   2349  2786  2840
# ThioPCD206_PEC_PToma       3191    162   1720  ...  3104   3128    47  3082
#
#                          Fabp5  Ifi27l2a  Cd5l   Vim  Hspa5  H2-Aa
# condition
# HP_PEC_NToma              2002      3427  3672  3313   3103   1977
# HP_PEC_PToma              2640      3602  3702  3538   3431   2986
# IL4_PEC_NToma             3816      5689  5957  5525   4236   1964
# IL4_PEC_PToma             2625      3302  3475  3277   2649   2293
# SS_PEC_NToma              1288      3411  2634  1579   1575    414
# SS_PEC_PToma               626      1407  1159   935    840    372
# ThioIL4PCD206_PEC_PToma   2936      1861   631  2965   2919   1922
# ThioPCD206_PEC_PToma      3182      3011  1213  3175   2185    546
#
# [8 rows x 30 columns]

# %%
data_inter_all_expressed_percent = pd.DataFrame((np.array(data_inter_all_expressed.groupby("condition").sum(0)).T/np.array(data_inter_all['condition'].value_counts().loc[data_inter_all_expressed.groupby("condition").sum(0).index])).T,
                                                index = data_inter_all_expressed.groupby("condition").sum(0).index, columns=data_inter_all_expressed.groupby("condition").sum(0).columns)

# %%
data_inter_all_expressed_percent
# Out:
#                            Retnla      Apoe      Saa3      Arg1      Prg4  \
# condition
# HP_PEC_NToma             0.980299  0.513002  0.999212  0.930129  0.991332
# HP_PEC_PToma             0.997140  0.739990  0.998960  0.974259  0.991940
# IL4_PEC_NToma            0.999843  0.437579  0.999214  0.937421  0.957547
# IL4_PEC_PToma            0.999725  0.708069  1.000000  0.966125  0.967777
# SS_PEC_NToma             0.558629  0.999424  0.993086  0.154422  0.993374
# SS_PEC_PToma             0.928721  0.999301  0.997904  0.229909  0.983229
# ThioIL4PCD206_PEC_PToma  1.000000  0.347313  0.060616  0.990498  0.007536
# ThioPCD206_PEC_PToma     0.026225  0.997502  0.193569  0.196691  0.009366
#
#                             Plac8    Lgals1    Tmsb10     Ccl24     Apoc2  \
# condition
# HP_PEC_NToma             0.203835  0.063042  0.819018  0.685317  0.470186
# HP_PEC_PToma             0.737389  0.163287  0.944098  0.772231  0.733749
# IL4_PEC_NToma            0.038365  0.078931  0.943868  0.399371  0.107075
# IL4_PEC_PToma            0.201322  0.161113  0.967227  0.527678  0.273478
# SS_PEC_NToma             0.016710  0.282916  0.540190  0.712763  0.703544
# SS_PEC_PToma             0.055206  0.345912  0.712788  0.844165  0.893082
# ThioIL4PCD206_PEC_PToma  0.072739  0.981979  0.988204  0.946265  0.051769
# ThioPCD206_PEC_PToma     0.089291  0.990946  0.996254  0.050578  0.536997
#
#                          ...      Cd63     Trem2      Mgl2      Cd36  \
# condition                ...
# HP_PEC_NToma             ...  0.091673  0.097715  0.355923  0.229840
# HP_PEC_PToma             ...  0.055122  0.137285  0.489600  0.328913
# IL4_PEC_NToma            ...  0.060535  0.080660  0.481289  0.516352
# IL4_PEC_PToma            ...  0.091435  0.133297  0.492426  0.645552
# SS_PEC_NToma             ...  0.153558  0.177470  0.016422  0.759435
# SS_PEC_PToma             ...  0.095038  0.221523  0.035639  0.880503
# ThioIL4PCD206_PEC_PToma  ...  0.913827  0.769659  0.912844  0.930537
# ThioPCD206_PEC_PToma     ...  0.969091  0.976584  0.014674  0.962223
#
#                             Fabp5  Ifi27l2a      Cd5l       Vim     Hspa5  \
# condition
# HP_PEC_NToma             0.525873  0.900184  0.964539  0.870239  0.815077
# HP_PEC_PToma             0.686427  0.936557  0.962559  0.919917  0.892096
# IL4_PEC_NToma            0.600000  0.894497  0.936635  0.868711  0.666038
# IL4_PEC_PToma            0.722941  0.909391  0.957037  0.902506  0.729551
# SS_PEC_NToma             0.371075  0.982714  0.758859  0.454912  0.453760
# SS_PEC_PToma             0.437456  0.983229  0.809923  0.653389  0.587002
# ThioIL4PCD206_PEC_PToma  0.961992  0.609764  0.206750  0.971494  0.956422
# ThioPCD206_PEC_PToma     0.993444  0.940056  0.378707  0.991258  0.682173
#
#                             H2-Aa
# condition
# HP_PEC_NToma             0.519307
# HP_PEC_PToma             0.776391
# IL4_PEC_NToma            0.308805
# IL4_PEC_PToma            0.631506
# SS_PEC_NToma             0.119274
# SS_PEC_PToma             0.259958
# ThioIL4PCD206_PEC_PToma  0.629751
# ThioPCD206_PEC_PToma     0.170465
#
# [8 rows x 30 columns]

# %%
# filter out the genes with gene expression >= 1.5
high_exp_gene = np.array(feature_scores_top40.index)[(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0)).mean() >= 1.5]

# %%
data_inter_all_expressed_percent[high_exp_gene]
# Out:
#                            Retnla      Apoe      Saa3      Arg1      Prg4  \
# condition
# HP_PEC_NToma             0.980299  0.513002  0.999212  0.930129  0.991332
# HP_PEC_PToma             0.997140  0.739990  0.998960  0.974259  0.991940
# IL4_PEC_NToma            0.999843  0.437579  0.999214  0.937421  0.957547
# IL4_PEC_PToma            0.999725  0.708069  1.000000  0.966125  0.967777
# SS_PEC_NToma             0.558629  0.999424  0.993086  0.154422  0.993374
# SS_PEC_PToma             0.928721  0.999301  0.997904  0.229909  0.983229
# ThioIL4PCD206_PEC_PToma  1.000000  0.347313  0.060616  0.990498  0.007536
# ThioPCD206_PEC_PToma     0.026225  0.997502  0.193569  0.196691  0.009366
#
#                            Tmsb10      Slpi       Pf4    S100a6  Ifi27l2a  \
# condition
# HP_PEC_NToma             0.819018  0.857631  0.791962  0.485947  0.900184
# HP_PEC_PToma             0.944098  0.977119  0.657826  0.606864  0.936557
# IL4_PEC_NToma            0.943868  0.688208  0.831604  0.804717  0.894497
# IL4_PEC_PToma            0.967227  0.940788  0.840540  0.875792  0.909391
# SS_PEC_NToma             0.540190  0.861135  0.980985  0.513973  0.982714
# SS_PEC_PToma             0.712788  0.961565  0.983229  0.665269  0.983229
# ThioIL4PCD206_PEC_PToma  0.988204  0.151376  0.740170  0.994102  0.609764
# ThioPCD206_PEC_PToma     0.996254  0.097721  0.838901  0.996254  0.940056
#
#                              Cd5l       Vim
# condition
# HP_PEC_NToma             0.964539  0.870239
# HP_PEC_PToma             0.962559  0.919917
# IL4_PEC_NToma            0.936635  0.868711
# IL4_PEC_PToma            0.957037  0.902506
# SS_PEC_NToma             0.758859  0.454912
# SS_PEC_PToma             0.809923  0.653389
# ThioIL4PCD206_PEC_PToma  0.206750  0.971494
# ThioPCD206_PEC_PToma     0.378707  0.991258

# %%
data_inter_all_expressed_percent = data_inter_all_expressed_percent[high_exp_gene]
data_inter_dotplot = pd.melt(data_inter_all_expressed_percent*100, var_name='Top 40 genes', value_name="Percent Expressed")

# %%
data_inter_all_expressed_percent.mean() < 0.5
# Out:
# Retnla      False
# Apoe        False
# Saa3        False
# Arg1        False
# Prg4        False
# Tmsb10      False
# Slpi        False
# Pf4         False
# S100a6      False
# Ifi27l2a    False
# Cd5l        False
# Vim         False
# dtype: bool

# %%
#data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*40)
data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*len(high_exp_gene))

# %%
data_inter_dotplot
# Out:
#    Top 40 genes  Percent Expressed               Conditions
# 0        Retnla          98.029945             HP_PEC_NToma
# 1        Retnla          99.713989             HP_PEC_PToma
# 2        Retnla          99.984277            IL4_PEC_NToma
# 3        Retnla          99.972459            IL4_PEC_PToma
# 4        Retnla          55.862864             SS_PEC_NToma
# ..          ...                ...                      ...
# 91          Vim          90.250620            IL4_PEC_PToma
# 92          Vim          45.491213             SS_PEC_NToma
# 93          Vim          65.338924             SS_PEC_PToma
# 94          Vim          97.149410  ThioIL4PCD206_PEC_PToma
# 95          Vim          99.125820     ThioPCD206_PEC_PToma
#
# [96 rows x 3 columns]

# %%
#data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0))['value']
data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[list(high_exp_gene) + ["condition"]].groupby("condition").mean(0))['value']

# %%
data_inter_dotplot
# Out:
#    Top 40 genes  Percent Expressed               Conditions  \
# 0        Retnla          98.029945             HP_PEC_NToma
# 1        Retnla          99.713989             HP_PEC_PToma
# 2        Retnla          99.984277            IL4_PEC_NToma
# 3        Retnla          99.972459            IL4_PEC_PToma
# 4        Retnla          55.862864             SS_PEC_NToma
# ..          ...                ...                      ...
# 91          Vim          90.250620            IL4_PEC_PToma
# 92          Vim          45.491213             SS_PEC_NToma
# 93          Vim          65.338924             SS_PEC_PToma
# 94          Vim          97.149410  ThioIL4PCD206_PEC_PToma
# 95          Vim          99.125820     ThioPCD206_PEC_PToma
#
#     Average Expression
# 0             3.424548
# 1             3.985334
# 2             5.699055
# 3             5.608158
# 4             1.382931
# ..                 ...
# 91            1.739486
# 92            0.721193
# 93            1.000421
# 94            2.565311
# 95            3.061798
#
# [96 rows x 4 columns]

# %%
data_inter_dotplot["Average Expression"] = [5 if AE >5 else AE for AE in data_inter_dotplot["Average Expression"]]

# %%
data_inter_dotplot["Average Expression"] = [1 if AE <1 else AE for AE in data_inter_dotplot["Average Expression"]]

# %%
data_inter_dotplot
# Out:
#    Top 40 genes  Percent Expressed               Conditions  \
# 0        Retnla          98.029945             HP_PEC_NToma
# 1        Retnla          99.713989             HP_PEC_PToma
# 2        Retnla          99.984277            IL4_PEC_NToma
# 3        Retnla          99.972459            IL4_PEC_PToma
# 4        Retnla          55.862864             SS_PEC_NToma
# ..          ...                ...                      ...
# 91          Vim          90.250620            IL4_PEC_PToma
# 92          Vim          45.491213             SS_PEC_NToma
# 93          Vim          65.338924             SS_PEC_PToma
# 94          Vim          97.149410  ThioIL4PCD206_PEC_PToma
# 95          Vim          99.125820     ThioPCD206_PEC_PToma
#
#     Average Expression
# 0             3.424548
# 1             3.985334
# 2             5.000000
# 3             5.000000
# 4             1.382931
# ..                 ...
# 91            1.739486
# 92            1.000000
# 93            1.000421
# 94            2.565311
# 95            3.061798
#
# [96 rows x 4 columns]

# %%
import altair as alt
range_ = ['#990000', '#CC0000', '#FF0000', '#FF3333', '#FF6666', '#FF9999', '#FFCCCC']
alt.Chart(data_inter_dotplot).mark_circle().encode(
    #x=alt.X('Top 40 genes:O', sort=feature_scores_top40.index.to_list()),
    x=alt.X('Top 40 genes:O', sort=high_exp_gene),
    #x = 'Top 40 genes:O',
    y = 'Conditions:O',
    size = 'Percent Expressed:Q',
    color = alt.Color(
            'Average Expression:Q',
            scale = alt.Scale(domain= [max(data_inter_dotplot['Average Expression']),min(data_inter_dotplot['Average Expression'])], range = range_))
)
# Out:
# alt.Chart(...)

# %%
# 1. 
intersect_genes = list(set(HP_PEC_NToma.index) & set(HP_PEC_PToma.index) & set(IL4_PEC_NToma.index) & set(IL4_PEC_PToma.index) & 
                       set(SS_PEC_NToma.index) & set(SS_PEC_PToma.index) & set(ThioIL4PCD206_PEC_PToma.index) & set(ThioPCD206_PEC_PToma.index))

HP_PEC_NToma_inter = HP_PEC_NToma.loc[intersect_genes].T
HP_PEC_NToma_inter["condition"] = 'TRM'
HP_PEC_PToma_inter = HP_PEC_PToma.loc[intersect_genes].T
HP_PEC_PToma_inter["condition"] = 'TRM'

IL4_PEC_NToma_inter = IL4_PEC_NToma.loc[intersect_genes].T
IL4_PEC_NToma_inter["condition"] = 'TRM'
IL4_PEC_PToma_inter = IL4_PEC_PToma.loc[intersect_genes].T
IL4_PEC_PToma_inter["condition"] = 'TRM'

SS_PEC_NToma_inter = SS_PEC_NToma.loc[intersect_genes].T
SS_PEC_NToma_inter["condition"] = 'TRM'
SS_PEC_PToma_inter = SS_PEC_PToma.loc[intersect_genes].T
SS_PEC_PToma_inter["condition"] = 'TRM'

ThioIL4PCD206_PEC_PToma_inter = ThioIL4PCD206_PEC_PToma.loc[intersect_genes].T
ThioIL4PCD206_PEC_PToma_inter["condition"] = 'M\u03C6mo'
ThioPCD206_PEC_PToma_inter = ThioPCD206_PEC_PToma.loc[intersect_genes].T
ThioPCD206_PEC_PToma_inter["condition"] = 'M\u03C6mo'

data_inter_all = pd.concat([HP_PEC_NToma_inter, HP_PEC_PToma_inter, IL4_PEC_NToma_inter, IL4_PEC_PToma_inter, SS_PEC_NToma_inter, SS_PEC_PToma_inter, ThioIL4PCD206_PEC_PToma_inter, ThioPCD206_PEC_PToma_inter])
data_inter_all['condition'].value_counts()/len(data_inter_all)
# Out:
# TRM     0.78282
# Mφmo    0.21718
# Name: condition, dtype: float64

# %%
import numpy as np
X = data_inter_all.loc[:,data_inter_all.columns[:-1]]
y = data_inter_all['condition']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# instantiate the classifier with n_estimators = 100
rfc = RandomForestClassifier(n_estimators=200, random_state = 0, class_weight={'TRM': 1, 'M\u03C6mo': 4})

# fit the model to the training set
rfc.fit(X_train, y_train)
# Predict on the test set results
y_pred = rfc.predict(X_test)

# Check accuracy score 
print('Model accuracy score with 200 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 200 decision-trees : 0.9994

# %%
sum(np.array(y_test == 'TRM',dtype = int))
# Out:
# 6814

# %%
import pickle
# save model
filename = '/home/sun/monocyte_scRNAseq/save_model/RF_200_7_3_TRMvsMO.sav'
pickle.dump(rfc, open(filename, 'wb'))

# %%
# view the feature scores
feature_scores = pd.Series(rfc.feature_importances_, index=X_train.columns).sort_values(ascending=False)
#feature_scores_top40 = feature_scores.loc[feature_scores.index[:40]]
feature_scores_top40 = feature_scores.loc[feature_scores.index[:30]]
feature_scores
# Out:
# X
# Prg4        0.106890
# Lgals1      0.086688
# Saa3        0.074429
# Serpinb2    0.071101
# Alox15      0.069753
#               ...
# Prr11       0.000003
# Asf1b       0.000003
# Cep55       0.000002
# Kif2c       0.000002
# BE692007    0.000001
# Length: 265, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 8))
ax = sns.barplot(x=feature_scores_top40, y=feature_scores_top40.index)
#ax.set_title("Visualize feature scores of the features")
ax.set_yticklabels(feature_scores_top40.index)
ax.set_xlabel("Gini importance score")
ax.set_ylabel("Top 30 genes")
plt.show()

# %%
data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0)
# Out:
# X                            Prg4    Lgals1      Saa3  Serpinb2    Alox15  \
# condition
# HP_PEC_NToma             3.018612  0.072159  3.982356  1.654023  2.346596
# HP_PEC_PToma             2.805707  0.169344  3.824384  1.253343  2.119247
# IL4_PEC_NToma            2.354775  0.112333  5.097136  1.740598  1.635050
# IL4_PEC_PToma            2.489546  0.203586  5.619777  1.709124  1.691822
# SS_PEC_NToma             3.765631  0.454618  3.918648  0.736844  1.959924
# SS_PEC_PToma             3.686857  0.523106  4.113107  0.737889  2.217307
# ThioIL4PCD206_PEC_PToma  0.007408  3.110764  0.072567  0.036867  0.006365
# ThioPCD206_PEC_PToma     0.010654  3.622603  0.275381  0.002615  0.001160
#
# X                            Cd63    Plxdc2      Ssh2    S100a6       Lpl  \
# condition
# HP_PEC_NToma             0.108375  2.143214  1.413732  0.770329  0.197466
# HP_PEC_PToma             0.055489  1.775543  1.547361  0.921667  0.460782
# IL4_PEC_NToma            0.085125  2.136784  1.425577  1.674335  0.039615
# IL4_PEC_PToma            0.105001  2.151858  1.462306  1.811027  0.076809
# SS_PEC_NToma             0.223404  1.562921  1.507729  0.932777  0.626771
# SS_PEC_PToma             0.120136  1.730640  1.868510  1.190818  0.850495
# ThioIL4PCD206_PEC_PToma  1.929310  0.118703  0.124773  3.297473  2.387539
# ThioPCD206_PEC_PToma     2.562290  0.033195  0.147893  3.232547  2.352434
#
# X                        ...    Rad51b     Folr2     Fabp7      Spp1  \
# condition                ...
# HP_PEC_NToma             ...  0.813382  0.029584  0.697816  0.356610
# HP_PEC_PToma             ...  0.520094  0.106639  0.701620  0.252625
# IL4_PEC_NToma            ...  0.853907  0.072408  0.614230  0.386000
# IL4_PEC_PToma            ...  0.700824  0.206110  0.754642  0.324517
# SS_PEC_NToma             ...  0.825895  0.078083  0.540917  0.010104
# SS_PEC_PToma             ...  0.604310  0.184826  0.832649  0.027604
# ThioIL4PCD206_PEC_PToma  ...  0.067693  0.464997  0.056336  0.719133
# ThioPCD206_PEC_PToma     ...  0.049589  0.727087  0.051828  2.749589
#
# X                            Sdc4      Arg1    Clec4e      Ccl2      Rgs1  \
# condition
# HP_PEC_NToma             0.007638  2.461090  0.470030  0.051962  0.482600
# HP_PEC_PToma             0.010179  2.689699  0.416268  0.032842  0.167609
# IL4_PEC_NToma            0.050100  2.487364  0.433155  0.025915  0.215641
# IL4_PEC_PToma            0.087462  2.540170  0.516163  0.035802  0.212884
# SS_PEC_NToma             0.022951  0.218003  0.330151  0.032379  0.361613
# SS_PEC_PToma             0.032703  0.315825  0.334721  0.019024  0.175023
# ThioIL4PCD206_PEC_PToma  0.826654  3.822934  0.042861  1.086128  0.595846
# ThioPCD206_PEC_PToma     0.214001  0.239253  0.047771  0.249649  1.005182
#
# X                         Pglyrp1
# condition
# HP_PEC_NToma             0.755089
# HP_PEC_PToma             0.410458
# IL4_PEC_NToma            0.623865
# IL4_PEC_PToma            0.603975
# SS_PEC_NToma             0.061463
# SS_PEC_PToma             0.078326
# ThioIL4PCD206_PEC_PToma  0.002814
# ThioPCD206_PEC_PToma     0.003678
#
# [8 rows x 30 columns]

# %%
data_inter_all_expressed
# Out:
#                     Prg4  Lgals1  Saa3  Serpinb2  Alox15  Cd63  Plxdc2  Ssh2  \
# AAACCTGAGTGGGCTA.1     1       0     1         0       1     0       1     0
# AAACCTGAGTTGAGAT.1     1       0     1         1       1     0       1     1
# AAACCTGTCGGAGCAA.1     1       1     1         1       1     0       1     1
# AAACGGGAGGCAATTA.1     1       0     1         0       1     0       1     0
# AAACGGGAGTCTCCTC.1     1       0     1         0       1     1       1     1
# ...                  ...     ...   ...       ...     ...   ...     ...   ...
# TTTGTCAGTCAAACTC.1     0       1     0         0       0     1       0     1
# TTTGTCAGTCCGACGT.1     0       1     1         0       0     1       0     1
# TTTGTCATCCACGTGG.1     0       1     0         0       0     1       0     0
# TTTGTCATCGCTTAGA.1     0       1     0         0       0     1       0     0
# TTTGTCATCTCTAGGA.1     0       1     0         0       0     1       0     0
#
#                     S100a6  Lpl  ...  Folr2  Fabp7  Spp1  Sdc4  Arg1  Clec4e  \
# AAACCTGAGTGGGCTA.1       0    0  ...      0      0     0     0     1       0
# AAACCTGAGTTGAGAT.1       1    0  ...      0      0     0     0     1       1
# AAACCTGTCGGAGCAA.1       1    0  ...      0      1     1     0     1       0
# AAACGGGAGGCAATTA.1       1    1  ...      0      0     0     0     1       0
# AAACGGGAGTCTCCTC.1       1    0  ...      0      1     0     0     1       1
# ...                    ...  ...  ...    ...    ...   ...   ...   ...     ...
# TTTGTCAGTCAAACTC.1       1    1  ...      1      0     1     0     0       0
# TTTGTCAGTCCGACGT.1       1    1  ...      1      0     1     1     1       0
# TTTGTCATCCACGTGG.1       1    1  ...      1      1     1     0     0       0
# TTTGTCATCGCTTAGA.1       1    1  ...      1      0     1     0     0       0
# TTTGTCATCTCTAGGA.1       1    1  ...      0      0     1     1     0       0
#
#                     Ccl2  Rgs1  Pglyrp1  condition
# AAACCTGAGTGGGCTA.1     0     1        0        TRM
# AAACCTGAGTTGAGAT.1     0     0        1        TRM
# AAACCTGTCGGAGCAA.1     0     1        0        TRM
# AAACGGGAGGCAATTA.1     0     0        0        TRM
# AAACGGGAGTCTCCTC.1     0     0        1        TRM
# ...                  ...   ...      ...        ...
# TTTGTCAGTCAAACTC.1     0     1        0       Mφmo
# TTTGTCAGTCCGACGT.1     0     1        0       Mφmo
# TTTGTCATCCACGTGG.1     0     1        0       Mφmo
# TTTGTCATCGCTTAGA.1     0     1        0       Mφmo
# TTTGTCATCTCTAGGA.1     0     1        0       Mφmo
#
# [28801 rows x 31 columns]

# %%
data_inter_all_expressed = pd.DataFrame(np.array(data_inter_all[feature_scores_top40.index.tolist()] >0, dtype=int), 
                                        columns=feature_scores_top40.index.tolist(), index=data_inter_all.index)
data_inter_all_expressed['condition'] = data_inter_all["condition"]
data_inter_all_expressed_percent = pd.DataFrame((np.array(data_inter_all_expressed.groupby("condition").sum(0)).T/np.array(data_inter_all['condition'].value_counts().loc[data_inter_all_expressed.groupby("condition").sum(0).index])).T,
                                                index = data_inter_all_expressed.groupby("condition").sum(0).index, columns=data_inter_all_expressed.groupby("condition").sum(0).columns)

data_inter_all_expressed.groupby("condition").sum(0)
# Out:
#                          Prg4  Lgals1  Saa3  Serpinb2  Alox15  Cd63  Plxdc2  \
# condition
# HP_PEC_NToma             3774     240  3804      3329    3677   349    3639
# HP_PEC_PToma             3815     628  3842      3072    3573   212    3317
# IL4_PEC_NToma            6090     502  6355      5483    5155   385    5903
# IL4_PEC_PToma            3514     585  3631      3241    3088   332    3448
# SS_PEC_NToma             3448     982  3447      1611    2984   533    2701
# SS_PEC_PToma             1407     495  1428       760    1355   136    1264
# ThioIL4PCD206_PEC_PToma    23    2997   185       103      21  2789     393
# ThioPCD206_PEC_PToma       30    3174   620         9       5  3104     146
#
#                          Ssh2  S100a6   Lpl  ...  Rad51b  Folr2  Fabp7  Spp1  \
# condition                                    ...
# HP_PEC_NToma             3158    1850   590  ...    2209    107   1995   855
# HP_PEC_PToma             3451    2334  1535  ...    1778    382   2271   748
# IL4_PEC_NToma            4838    5118   188  ...    3613    359   2748  1606
# IL4_PEC_PToma            2997    3180   254  ...    2007    657   2113   874
# SS_PEC_NToma             2660    1784  1375  ...    1760    185   1223    10
# SS_PEC_PToma             1316     952   812  ...     614    193    817    10
# ThioIL4PCD206_PEC_PToma   419    3034  2868  ...     246   1313    191  1506
# ThioPCD206_PEC_PToma      597    3191  3039  ...     230   2008    255  3037
#
#                          Sdc4  Arg1  Clec4e  Ccl2  Rgs1  Pglyrp1
# condition
# HP_PEC_NToma               26  3541    1449   177  1373     2025
# HP_PEC_PToma               41  3747    1590   133   637     1414
# IL4_PEC_NToma             233  5962    2000   148  1071     2771
# IL4_PEC_PToma             283  3508    1535   129   714     1679
# SS_PEC_NToma               58   536     796    81   806      157
# SS_PEC_PToma               35   329     391    21   188      100
# ThioIL4PCD206_PEC_PToma  1902  3023     142  1964  1504        9
# ThioPCD206_PEC_PToma      892   630     214   775  2455       15
#
# [8 rows x 30 columns]

# %%
data_inter_all_expressed_percent = pd.DataFrame((np.array(data_inter_all_expressed.groupby("condition").sum(0)).T/np.array(data_inter_all['condition'].value_counts().loc[data_inter_all_expressed.groupby("condition").sum(0).index])).T,
                                                index = data_inter_all_expressed.groupby("condition").sum(0).index, columns=data_inter_all_expressed.groupby("condition").sum(0).columns)
# filter out the genes with gene expression >= 1.5
high_exp_gene = np.array(feature_scores_top40.index)[(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0)).mean() >= 1.5]
data_inter_all_expressed_percent = data_inter_all_expressed_percent[high_exp_gene]

# %%
data_inter_dotplot = pd.melt(data_inter_all_expressed_percent*100, var_name='Top 40 genes', value_name="Percent Expressed")
#data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*40)
data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*len(high_exp_gene))
#data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0))['value']
data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[list(high_exp_gene) + ["condition"]].groupby("condition").mean(0))['value']
data_inter_dotplot["Average Expression"] = [5 if AE >5 else AE for AE in data_inter_dotplot["Average Expression"]]
data_inter_dotplot["Average Expression"] = [1 if AE <1 else AE for AE in data_inter_dotplot["Average Expression"]]
data_inter_dotplot
# Out:
#    Top 40 genes  Percent Expressed               Conditions  \
# 0          Prg4          99.133176             HP_PEC_NToma
# 1          Prg4          99.193968             HP_PEC_PToma
# 2          Prg4          95.754717            IL4_PEC_NToma
# 3          Prg4          96.777747            IL4_PEC_PToma
# 4          Prg4          99.337367             SS_PEC_NToma
# ..          ...                ...                      ...
# 59         Arg1          96.612503            IL4_PEC_PToma
# 60         Arg1          15.442236             SS_PEC_NToma
# 61         Arg1          22.990915             SS_PEC_PToma
# 62         Arg1          99.049803  ThioIL4PCD206_PEC_PToma
# 63         Arg1          19.669060     ThioPCD206_PEC_PToma
#
#     Average Expression
# 0             3.018612
# 1             2.805707
# 2             2.354775
# 3             2.489546
# 4             3.765631
# ..                 ...
# 59            2.540170
# 60            1.000000
# 61            1.000000
# 62            3.822934
# 63            1.000000
#
# [64 rows x 4 columns]

# %%
data_inter_all_expressed_percent.mean() < 0.5
# Out:
# Prg4      False
# Saa3      False
# S100a6    False
# Cd5l      False
# Slpi      False
# Tmsb10    False
# Vim       False
# Arg1      False
# dtype: bool

# %%
import altair as alt
y_axis = ['TRM', 'M\u03C6mo']
range_ = ['#990000', '#CC0000', '#FF0000', '#FF3333', '#FF6666', '#FF9999', '#FFCCCC']
alt.Chart(data_inter_dotplot).mark_circle().encode(
    #x=alt.X('Top 40 genes:O', sort=feature_scores_top40.index.to_list()),
    x=alt.X('Top 40 genes:O', sort=high_exp_gene),
    #x = 'Top 40 genes:O',
    y = alt.Y('Conditions:O', sort=y_axis),
    size = 'Percent Expressed:Q',
    color = alt.Color(
            'Average Expression:Q',
            #scale = alt.Scale(domain= [max(data_inter_dotplot['Average Expression']),min(data_inter_dotplot['Average Expression'])], scheme = 'redblue'))
            scale = alt.Scale(domain= [max(data_inter_dotplot['Average Expression']),min(data_inter_dotplot['Average Expression'])], range = range_))
)
# Out:
# alt.Chart(...)

# %%
# 2. 
intersect_genes = list(set(HP_PEC_NToma.index) & set(HP_PEC_PToma.index) & set(IL4_PEC_NToma.index) & set(IL4_PEC_PToma.index) & 
                       set(SS_PEC_NToma.index) & set(SS_PEC_PToma.index))

HP_PEC_NToma_inter = HP_PEC_NToma.loc[intersect_genes].T
HP_PEC_NToma_inter["condition"] = 'TRM_em'
HP_PEC_PToma_inter = HP_PEC_PToma.loc[intersect_genes].T
HP_PEC_PToma_inter["condition"] = 'TRM_mo'

IL4_PEC_NToma_inter = IL4_PEC_NToma.loc[intersect_genes].T
IL4_PEC_NToma_inter["condition"] = 'TRM_em'
IL4_PEC_PToma_inter = IL4_PEC_PToma.loc[intersect_genes].T
IL4_PEC_PToma_inter["condition"] = 'TRM_mo'

SS_PEC_NToma_inter = SS_PEC_NToma.loc[intersect_genes].T
SS_PEC_NToma_inter["condition"] = 'TRM_em'
SS_PEC_PToma_inter = SS_PEC_PToma.loc[intersect_genes].T
SS_PEC_PToma_inter["condition"] = 'TRM_mo'


data_inter_all = pd.concat([HP_PEC_NToma_inter, HP_PEC_PToma_inter, IL4_PEC_NToma_inter, IL4_PEC_PToma_inter, SS_PEC_NToma_inter, SS_PEC_PToma_inter])
data_inter_all['condition'].value_counts()/len(data_inter_all)
# Out:
# TRM_em    0.604897
# TRM_mo    0.395103
# Name: condition, dtype: float64

# %%
HP_PEC_NToma_inter = HP_PEC_NToma.loc[intersect_genes].T
HP_PEC_NToma_inter["condition"] = "HP_PEC_NToma"
HP_PEC_PToma_inter = HP_PEC_PToma.loc[intersect_genes].T
HP_PEC_PToma_inter["condition"] = "HP_PEC_PToma"

IL4_PEC_NToma_inter = IL4_PEC_NToma.loc[intersect_genes].T
IL4_PEC_NToma_inter["condition"] = "IL4_PEC_NToma"
IL4_PEC_PToma_inter = IL4_PEC_PToma.loc[intersect_genes].T
IL4_PEC_PToma_inter["condition"] = "IL4_PEC_PToma"

SS_PEC_NToma_inter = SS_PEC_NToma.loc[intersect_genes].T
SS_PEC_NToma_inter["condition"] = "SS_PEC_NToma"
SS_PEC_PToma_inter = SS_PEC_PToma.loc[intersect_genes].T
SS_PEC_PToma_inter["condition"] = "SS_PEC_PToma"

data_inter_all = pd.concat([HP_PEC_NToma_inter, HP_PEC_PToma_inter, IL4_PEC_NToma_inter, IL4_PEC_PToma_inter, SS_PEC_NToma_inter, SS_PEC_PToma_inter])
data_inter_all['condition'].value_counts()/len(data_inter_all)
# Out:
# IL4_PEC_NToma    0.282090
# HP_PEC_PToma     0.170585
# HP_PEC_NToma     0.168855
# IL4_PEC_PToma    0.161049
# SS_PEC_NToma     0.153952
# SS_PEC_PToma     0.063470
# Name: condition, dtype: float64

# %%
len(intersect_genes)
# Out:
# 412

# %%
import numpy as np
X = data_inter_all.loc[:,data_inter_all.columns[:-1]]
y = data_inter_all['condition']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# instantiate the classifier with n_estimators = 100
rfc = RandomForestClassifier(n_estimators=200, random_state=0, class_weight={'TRM_em': 1, 'TRM_mo': 2})

# fit the model to the training set
rfc.fit(X_train, y_train)
# Predict on the test set results
y_pred = rfc.predict(X_test)

# Check accuracy score 
print('Model accuracy score with 200 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 200 decision-trees : 0.8406

# %%
import pickle
# save model
filename = '/home/sun/monocyte_scRNAseq/save_model/RF_200_7_3_TRM_emvsTRM_mo.sav'
pickle.dump(rfc, open(filename, 'wb'))

# %%
# view the feature scores
feature_scores = pd.Series(rfc.feature_importances_, index=X_train.columns).sort_values(ascending=False)
feature_scores_top40 = feature_scores.loc[feature_scores.index[:30]]
feature_scores

import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 8))
ax = sns.barplot(x=feature_scores_top40, y=feature_scores_top40.index)
#ax.set_title("Visualize feature scores of the features")
ax.set_yticklabels(feature_scores_top40.index)
ax.set_xlabel("Gini importance score")
ax.set_ylabel("Top 30 genes")
plt.show()

# %%
data_inter_all_expressed = pd.DataFrame(np.array(data_inter_all[feature_scores_top40.index.tolist()] >0, dtype=int), 
                                        columns=feature_scores_top40.index.tolist(), index=data_inter_all.index)
data_inter_all_expressed['condition'] = data_inter_all["condition"]
data_inter_all_expressed_percent = pd.DataFrame((np.array(data_inter_all_expressed.groupby("condition").sum(0)).T/np.array(data_inter_all['condition'].value_counts().loc[data_inter_all_expressed.groupby("condition").sum(0).index])).T,
                                                index = data_inter_all_expressed.groupby("condition").sum(0).index, columns=data_inter_all_expressed.groupby("condition").sum(0).columns)

#data_inter_all_expressed.groupby("condition").sum(0)
data_inter_all_expressed_percent = pd.DataFrame((np.array(data_inter_all_expressed.groupby("condition").sum(0)).T/np.array(data_inter_all['condition'].value_counts().loc[data_inter_all_expressed.groupby("condition").sum(0).index])).T,
                                                index = data_inter_all_expressed.groupby("condition").sum(0).index, columns=data_inter_all_expressed.groupby("condition").sum(0).columns)
# filter out the genes with gene expression >= 1.5
high_exp_gene = np.array(feature_scores_top40.index)[(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0)).mean() >= 1.5]
data_inter_all_expressed_percent = data_inter_all_expressed_percent[high_exp_gene]

data_inter_dotplot = pd.melt(data_inter_all_expressed_percent*100, var_name='Top 40 genes', value_name="Percent Expressed")
#data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*40)
data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*len(high_exp_gene))
data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0))['value']
data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[list(high_exp_gene) + ["condition"]].groupby("condition").mean(0))['value']
data_inter_dotplot["Average Expression"] = [5 if AE >5 else AE for AE in data_inter_dotplot["Average Expression"]]
data_inter_dotplot["Average Expression"] = [1 if AE <1 else AE for AE in data_inter_dotplot["Average Expression"]]
data_inter_dotplot
# Out:
#    Top 40 genes  Percent Expressed     Conditions  Average Expression
# 0          Slpi          85.763068   HP_PEC_NToma            2.299803
# 1          Slpi          97.711908   HP_PEC_PToma            3.168739
# 2          Slpi          68.820755  IL4_PEC_NToma            1.720857
# 3          Slpi          94.078766  IL4_PEC_PToma            2.859426
# 4          Slpi          86.113512   SS_PEC_NToma            2.701483
# 5          Slpi          96.156534   SS_PEC_PToma            3.237990
# 6         Chil3          99.658524   HP_PEC_NToma            4.314594
# 7         Chil3         100.000000   HP_PEC_PToma            5.000000
# 8         Chil3          97.625786  IL4_PEC_NToma            3.959391
# 9         Chil3          99.862297  IL4_PEC_PToma            4.891624
# 10        Chil3           0.979545   SS_PEC_NToma            1.000000
# 11        Chil3           8.525507   SS_PEC_PToma            1.000000
# 12       Retnla          98.029945   HP_PEC_NToma            3.424548
# 13       Retnla          99.713989   HP_PEC_PToma            3.985334
# 14       Retnla          99.984277  IL4_PEC_NToma            5.000000
# 15       Retnla          99.972459  IL4_PEC_PToma            5.000000
# 16       Retnla          55.862864   SS_PEC_NToma            1.382931
# 17       Retnla          92.872117   SS_PEC_PToma            2.888250
# 18         Apoe          51.300236   HP_PEC_NToma            1.006032
# 19         Apoe          73.998960   HP_PEC_PToma            1.523834
# 20         Apoe          43.757862  IL4_PEC_NToma            1.000000
# 21         Apoe          70.806940  IL4_PEC_PToma            1.167165
# 22         Apoe          99.942380   SS_PEC_NToma            5.000000
# 23         Apoe          99.930119   SS_PEC_PToma            5.000000
# 24         Saa3          99.921198   HP_PEC_NToma            3.982356
# 25         Saa3          99.895996   HP_PEC_PToma            3.824384
# 26         Saa3          99.921384  IL4_PEC_NToma            5.000000
# 27         Saa3         100.000000  IL4_PEC_PToma            5.000000
# 28         Saa3          99.308557   SS_PEC_NToma            3.918648
# 29         Saa3          99.790356   SS_PEC_PToma            4.113107
# 30       Wfdc17          99.947465   HP_PEC_NToma            4.424148
# 31       Wfdc17          99.973999   HP_PEC_PToma            4.165121
# 32       Wfdc17          99.433962  IL4_PEC_NToma            4.009832
# 33       Wfdc17          99.697053  IL4_PEC_PToma            4.151299
# 34       Wfdc17          99.827139   SS_PEC_NToma            4.877342
# 35       Wfdc17          99.580713   SS_PEC_PToma            4.683404
# 36       Malat1          99.632256   HP_PEC_NToma            3.842491
# 37       Malat1          99.427977   HP_PEC_PToma            3.635353
# 38       Malat1          98.207547  IL4_PEC_NToma            3.595975
# 39       Malat1          99.063619  IL4_PEC_PToma            3.852312
# 40       Malat1          99.798329   SS_PEC_NToma            4.380500
# 41       Malat1          99.371069   SS_PEC_PToma            4.414974
# 42          Pf4          79.196217   HP_PEC_NToma            1.671451
# 43          Pf4          65.782631   HP_PEC_PToma            1.106055
# 44          Pf4          83.160377  IL4_PEC_NToma            2.047060
# 45          Pf4          84.053980  IL4_PEC_PToma            2.026281
# 46          Pf4          98.098531   SS_PEC_NToma            3.716688
# 47          Pf4          98.322851   SS_PEC_PToma            3.674163
# 48         Prg4          99.133176   HP_PEC_NToma            3.018612
# 49         Prg4          99.193968   HP_PEC_PToma            2.805707
# 50         Prg4          95.754717  IL4_PEC_NToma            2.354775
# 51         Prg4          96.777747  IL4_PEC_PToma            2.489546
# 52         Prg4          99.337367   SS_PEC_NToma            3.765631
# 53         Prg4          98.322851   SS_PEC_PToma            3.686857

# %%
data_inter_all_expressed_percent.mean() < 0.5
# Out:
# Slpi      False
# Chil3     False
# Retnla    False
# Apoe      False
# Saa3      False
# Wfdc17    False
# Malat1    False
# Pf4       False
# Prg4      False
# dtype: bool

# %%
import altair as alt
#y_axis = ['TRM_em', 'TRM_mo']
y_axis = ["HP_PEC_NToma",  "IL4_PEC_NToma", "SS_PEC_NToma", "HP_PEC_PToma","IL4_PEC_PToma", "SS_PEC_PToma"]
range_ = ['#990000', '#CC0000', '#FF0000', '#FF3333', '#FF6666', '#FF9999', '#FFCCCC']
alt.Chart(data_inter_dotplot).mark_circle().encode(
    #x=alt.X('Top 40 genes:O', sort=feature_scores_top40.index.to_list()),
    x=alt.X('Top 40 genes:O', sort=high_exp_gene),
    #x = 'Top 40 genes:O',
    y = alt.Y('Conditions:O', sort=y_axis),
    size = 'Percent Expressed:Q',
    color = alt.Color(
            'Average Expression:Q',
            #scale = alt.Scale(domain= [max(data_inter_dotplot['Average Expression']),min(data_inter_dotplot['Average Expression'])], scheme = 'redblue'))
            scale = alt.Scale(domain= [max(data_inter_dotplot['Average Expression']),min(data_inter_dotplot['Average Expression'])], range = range_))
)
# Out:
# alt.Chart(...)

# %%
# 3. 
intersect_genes = list(set(HP_PEC_NToma.index) & set(HP_PEC_PToma.index) & set(IL4_PEC_NToma.index) & set(IL4_PEC_PToma.index))

HP_PEC_NToma_inter = HP_PEC_NToma.loc[intersect_genes].T
HP_PEC_NToma_inter["condition"] = 'HP'
HP_PEC_PToma_inter = HP_PEC_PToma.loc[intersect_genes].T
HP_PEC_PToma_inter["condition"] = 'HP'

IL4_PEC_NToma_inter = IL4_PEC_NToma.loc[intersect_genes].T
IL4_PEC_NToma_inter["condition"] = 'IL4'
IL4_PEC_PToma_inter = IL4_PEC_PToma.loc[intersect_genes].T
IL4_PEC_PToma_inter["condition"] = 'IL4'



data_inter_all = pd.concat([HP_PEC_NToma_inter, HP_PEC_PToma_inter, IL4_PEC_NToma_inter, IL4_PEC_PToma_inter])
data_inter_all['condition'].value_counts()/len(data_inter_all)
# Out:
# IL4    0.566255
# HP     0.433745
# Name: condition, dtype: float64

# %%
HP_PEC_NToma_inter = HP_PEC_NToma.loc[intersect_genes].T
HP_PEC_NToma_inter["condition"] = "HP_PEC_NToma"
HP_PEC_PToma_inter = HP_PEC_PToma.loc[intersect_genes].T
HP_PEC_PToma_inter["condition"] = "HP_PEC_PToma"

IL4_PEC_NToma_inter = IL4_PEC_NToma.loc[intersect_genes].T
IL4_PEC_NToma_inter["condition"] = "IL4_PEC_NToma"
IL4_PEC_PToma_inter = IL4_PEC_PToma.loc[intersect_genes].T
IL4_PEC_PToma_inter["condition"] = "IL4_PEC_PToma"

data_inter_all = pd.concat([HP_PEC_NToma_inter, HP_PEC_PToma_inter, IL4_PEC_NToma_inter, IL4_PEC_PToma_inter])
data_inter_all['condition'].value_counts()/len(data_inter_all)
# Out:
# IL4_PEC_NToma    0.360462
# HP_PEC_PToma     0.217978
# HP_PEC_NToma     0.215767
# IL4_PEC_PToma    0.205792
# Name: condition, dtype: float64

# %%
len(intersect_genes)
# Out:
# 742

# %%
import numpy as np
X = data_inter_all.loc[:,data_inter_all.columns[:-1]]
y = data_inter_all['condition']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# instantiate the classifier with n_estimators = 100
rfc = RandomForestClassifier(n_estimators=200, random_state=0)

# fit the model to the training set
rfc.fit(X_train, y_train)
# Predict on the test set results
y_pred = rfc.predict(X_test)

# Check accuracy score 
print('Model accuracy score with 200 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 200 decision-trees : 0.9958

# %%
import pickle
# save model
filename = '/home/sun/monocyte_scRNAseq/save_model/RF_200_7_3_HPvsIL4.sav'
pickle.dump(rfc, open(filename, 'wb'))

# %%
# view the feature scores
feature_scores = pd.Series(rfc.feature_importances_, index=X_train.columns).sort_values(ascending=False)
feature_scores_top40 = feature_scores.loc[feature_scores.index[:30]]
feature_scores

import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 8))
ax = sns.barplot(x=feature_scores_top40, y=feature_scores_top40.index)
#ax.set_title("Visualize feature scores of the features")
ax.set_yticklabels(feature_scores_top40.index)
ax.set_xlabel("Gini importance score")
ax.set_ylabel("Top 30 genes")
plt.show()

# %%
data_inter_all_expressed = pd.DataFrame(np.array(data_inter_all[feature_scores_top40.index.tolist()] >0, dtype=int), 
                                        columns=feature_scores_top40.index.tolist(), index=data_inter_all.index)
data_inter_all_expressed['condition'] = data_inter_all["condition"]
data_inter_all_expressed_percent = pd.DataFrame((np.array(data_inter_all_expressed.groupby("condition").sum(0)).T/np.array(data_inter_all['condition'].value_counts().loc[data_inter_all_expressed.groupby("condition").sum(0).index])).T,
                                                index = data_inter_all_expressed.groupby("condition").sum(0).index, columns=data_inter_all_expressed.groupby("condition").sum(0).columns)

#data_inter_all_expressed.groupby("condition").sum(0)
data_inter_all_expressed_percent = pd.DataFrame((np.array(data_inter_all_expressed.groupby("condition").sum(0)).T/np.array(data_inter_all['condition'].value_counts().loc[data_inter_all_expressed.groupby("condition").sum(0).index])).T,
                                                index = data_inter_all_expressed.groupby("condition").sum(0).index, columns=data_inter_all_expressed.groupby("condition").sum(0).columns)
# filter out the genes with gene expression >= 1.5
high_exp_gene = np.array(feature_scores_top40.index)[(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0)).mean() >= 1.5]
data_inter_all_expressed_percent = data_inter_all_expressed_percent[high_exp_gene]

data_inter_dotplot = pd.melt(data_inter_all_expressed_percent*100, var_name='Top 40 genes', value_name="Percent Expressed")
#data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*40)
#data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[feature_scores_top40.index.tolist() + ["condition"]].groupby("condition").mean(0))['value']
data_inter_dotplot['Conditions'] = np.array(data_inter_all_expressed_percent.index.tolist()*len(high_exp_gene))
data_inter_dotplot['Average Expression'] = pd.melt(data_inter_all[list(high_exp_gene) + ["condition"]].groupby("condition").mean(0))['value']
data_inter_dotplot["Average Expression"] = [5 if AE >5 else AE for AE in data_inter_dotplot["Average Expression"]]
data_inter_dotplot["Average Expression"] = [1 if AE <1 else AE for AE in data_inter_dotplot["Average Expression"]]
data_inter_dotplot
# Out:
#    Top 40 genes  Percent Expressed     Conditions  Average Expression
# 0        Retnla          98.029945   HP_PEC_NToma            3.424548
# 1        Retnla          99.713989   HP_PEC_PToma            3.985334
# 2        Retnla          99.984277  IL4_PEC_NToma            5.000000
# 3        Retnla          99.972459  IL4_PEC_PToma            5.000000
# 4          Saa3          99.921198   HP_PEC_NToma            3.982356
# 5          Saa3          99.895996   HP_PEC_PToma            3.824384
# 6          Saa3          99.921384  IL4_PEC_NToma            5.000000
# 7          Saa3         100.000000  IL4_PEC_PToma            5.000000
# 8          Lyz2          99.133176   HP_PEC_NToma            3.721559
# 9          Lyz2          99.817993   HP_PEC_PToma            3.876810
# 10         Lyz2          88.191824  IL4_PEC_NToma            2.279306
# 11         Lyz2          95.758744  IL4_PEC_PToma            2.802937
# 12          Trf          91.121618   HP_PEC_NToma            1.886470
# 13          Trf          95.813833   HP_PEC_PToma            1.967396
# 14          Trf          62.877358  IL4_PEC_NToma            1.018362
# 15          Trf          76.149821  IL4_PEC_PToma            1.195948
# 16         Prg4          99.133176   HP_PEC_NToma            3.018612
# 17         Prg4          99.193968   HP_PEC_PToma            2.805707
# 18         Prg4          95.754717  IL4_PEC_NToma            2.354775
# 19         Prg4          96.777747  IL4_PEC_PToma            2.489546
# 20       Tmsb10          81.901760   HP_PEC_NToma            1.758234
# 21       Tmsb10          94.409776   HP_PEC_PToma            2.473749
# 22       Tmsb10          94.386792  IL4_PEC_NToma            2.797925
# 23       Tmsb10          96.722666  IL4_PEC_PToma            2.772076
# 24         Ccl6          99.658524   HP_PEC_NToma            3.220475
# 25         Ccl6          99.661986   HP_PEC_PToma            3.108961
# 26         Ccl6          97.877358  IL4_PEC_NToma            2.767035
# 27         Ccl6          98.540347  IL4_PEC_PToma            2.857173
# 28        Thbs1          94.273706   HP_PEC_NToma            2.123440
# 29        Thbs1          96.229849   HP_PEC_PToma            2.118094
# 30        Thbs1          74.245283  IL4_PEC_NToma            1.400783
# 31        Thbs1          84.356926  IL4_PEC_PToma            1.583805
# 32         Actb          99.947465   HP_PEC_NToma            3.964816
# 33         Actb         100.000000   HP_PEC_PToma            3.896611
# 34         Actb          99.984277  IL4_PEC_NToma            4.470675
# 35         Actb          99.972459  IL4_PEC_PToma            4.421272
# 36       Alox15          96.585238   HP_PEC_NToma            2.346596
# 37       Alox15          92.901716   HP_PEC_PToma            2.119247
# 38       Alox15          81.053459  IL4_PEC_NToma            1.635050
# 39       Alox15          85.045442  IL4_PEC_PToma            1.691822
# 40          Pf4          79.196217   HP_PEC_NToma            1.671451
# 41          Pf4          65.782631   HP_PEC_PToma            1.106055
# 42          Pf4          83.160377  IL4_PEC_NToma            2.047060
# 43          Pf4          84.053980  IL4_PEC_PToma            2.026281
# 44         Arg1          93.012871   HP_PEC_NToma            2.461090
# 45         Arg1          97.425897   HP_PEC_PToma            2.689699
# 46         Arg1          93.742138  IL4_PEC_NToma            2.487364
# 47         Arg1          96.612503  IL4_PEC_PToma            2.540170
# 48        Chil3          99.658524   HP_PEC_NToma            4.314594
# 49        Chil3         100.000000   HP_PEC_PToma            5.000000
# 50        Chil3          97.625786  IL4_PEC_NToma            3.959391
# 51        Chil3          99.862297  IL4_PEC_PToma            4.891624
# 52       Wfdc17          99.947465   HP_PEC_NToma            4.424148
# 53       Wfdc17          99.973999   HP_PEC_PToma            4.165121
# 54       Wfdc17          99.433962  IL4_PEC_NToma            4.009832
# 55       Wfdc17          99.697053  IL4_PEC_PToma            4.151299

# %%
data_inter_all_expressed_percent.mean() < 0.5
# Out:
# Retnla    False
# Saa3      False
# Lyz2      False
# Trf       False
# Prg4      False
# Tmsb10    False
# Ccl6      False
# Thbs1     False
# Actb      False
# Alox15    False
# Pf4       False
# Arg1      False
# Chil3     False
# Wfdc17    False
# dtype: bool

# %%
import altair as alt
#y_axis = ['IL4', 'HP']
y_axis = [ "IL4_PEC_NToma","IL4_PEC_PToma", "HP_PEC_NToma","HP_PEC_PToma"]
range_ = ['#990000', '#CC0000', '#FF0000', '#FF3333', '#FF6666', '#FF9999', '#FFCCCC']
alt.Chart(data_inter_dotplot).mark_circle().encode(
    #x=alt.X('Top 40 genes:O', sort=feature_scores_top40.index.to_list()),
    x=alt.X('Top 40 genes:O', sort=high_exp_gene),
    #x = 'Top 40 genes:O',
    y = alt.Y('Conditions:O', sort=y_axis),
    size = 'Percent Expressed:Q',
    color = alt.Color(
            'Average Expression:Q',
            #scale = alt.Scale(domain= [max(data_inter_dotplot['Average Expression']),min(data_inter_dotplot['Average Expression'])], scheme = 'redblue'))
            scale = alt.Scale(domain= [max(data_inter_dotplot['Average Expression']),min(data_inter_dotplot['Average Expression'])], range = range_))
)
# Out:
# alt.Chart(...)
